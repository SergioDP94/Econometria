# %% [markdown]
# # **Capítulo 1 Problema 4**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import wooldridge as woo
import pandas as pd
import numpy as np

# %%
# Cargar la base de datos JTRAIN2
data = woo.data('jtrain2')

# i) Proporción de hombres que recibieron capacitación (train == 1)
train_prop = data['train'].mean()
print(f"Proporción de hombres que recibieron capacitación laboral: {train_prop:.2%}")
# Out:
# Proporción de hombres que recibieron capacitación laboral: 41.57%

# %%
# ii) Promedio de ingresos en 1978 (re78) según capacitación
re78_train = data.loc[data['train'] == 1, 're78'].mean()
re78_no_train = data.loc[data['train'] == 0, 're78'].mean()

print(f"Ingresos promedio en 1978 para hombres con capacitación: ${re78_train:.2f}")
print(f"Ingresos promedio en 1978 para hombres sin capacitación: ${re78_no_train:.2f}")
# Out:
# Ingresos promedio en 1978 para hombres con capacitación: $6.35
# Ingresos promedio en 1978 para hombres sin capacitación: $4.55

# %%
# Diferencia económica
diff_income = re78_train - re78_no_train
print(f"Diferencia económica en ingresos promedio: ${diff_income:.2f}")
# Out:
# Diferencia económica en ingresos promedio: $1.79

# %%
# iii) Proporción desempleada en 1978 según capacitación
unem_train = data.loc[data['train'] == 1, 'unem78'].mean()
unem_no_train = data.loc[data['train'] == 0, 'unem78'].mean()
print(f"Proporción desempleada en 1978 para hombres con capacitación: {unem_train:.2%}")
print(f"Proporción desempleada en 1978 para hombres sin capacitación: {unem_no_train:.2%}")
# Out:
# Proporción desempleada en 1978 para hombres con capacitación: 24.32%
# Proporción desempleada en 1978 para hombres sin capacitación: 35.38%

# %%
# iv) Evaluación de la efectividad del programa
print("El programa parece haber tenido un impacto positivo en los ingresos y el desempleo.")
# Out:
# El programa parece haber tenido un impacto positivo en los ingresos y el desempleo.
